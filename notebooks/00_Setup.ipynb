# %% [markdown]
# **Este notebook foi adaptado para Databricks Free Edition
# Novo Padrão de Organização**
#
# Catálogo: workspace
#
# Schema: lhdw
#
# Volumes: landingzone, bronze, silver, gold
#
# Estrutura de pastas: /Volumes/workspace/lhdw/landingzone/vendas/processar
#
# /Volumes/workspace/lhdw/landingzone/vendas/processado
#
# /Volumes/workspace/lhdw/bronze
#
# /Volumes/workspace/lhdw/silver
#
# /Volumes/workspace/lhdw/gold

# %%
# Criar uma pasta no Databricks para vinculo
#Criando um Schema 
spark.sql("CREATE SCHEMA IF NOT EXISTS workspace.lhdw COMMENT 'Schema LHDW'") 
# Create volumes in Databricks 
spark.sql("CREATE VOLUME IF NOT EXISTS workspace.lhdw.landingzone COMMENT 'Landing zone volume'") 
spark.sql("CREATE VOLUME IF NOT EXISTS workspace.lhdw.bronze COMMENT 'Bronze volume'") 
spark.sql("CREATE VOLUME IF NOT EXISTS workspace.lhdw.silver COMMENT 'Silver volume'") 
spark.sql("CREATE VOLUME IF NOT EXISTS workspace.lhdw.gold COMMENT 'Gold volume'")
 
# Criar uma pasta no Databricks para vinculo # Criando diretorios no DBFS 
dbutils.fs.mkdirs("dbfs:/Volumes/workspace/lhdw/landingzone/vendas/processar") 
dbutils.fs.mkdirs("dbfs:/Volumes/workspace/lhdw/landingzone/vendas/processado") 
dbutils.fs.mkdirs("dbfs:/Volumes/workspace/lhdw/bronze") 
dbutils.fs.mkdirs("dbfs:/Volumes/workspace/lhdw/silver") 
dbutils.fs.mkdirs("dbfs:/Volumes/workspace/lhdw/gold")
# Out:
# True

# %%
# %sql
SHOW VOLUMES
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>database</th><th>volume_name</th></tr></thead><tbody></tbody></table></div>

# %%
# %sql
SHOW SCHEMAS IN workspace;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>databaseName</th></tr></thead><tbody><tr><td>bcdata</td></tr><tr><td>default</td></tr><tr><td>information_schema</td></tr><tr><td>lhdw</td></tr></tbody></table></div>

# %%
# %sql
SHOW TABLES IN workspace.lhdw;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>database</th><th>tableName</th><th>isTemporary</th></tr></thead><tbody></tbody></table></div>

# %%
# %fs ls
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/Volumes/</td><td>Volumes/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/Workspace/</td><td>Workspace/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/</td><td>databricks-datasets/</td><td>0</td><td>0</td></tr></tbody></table></div>

# %%
# Lista o conteúdo do Volume bronze
dbutils.fs.ls("/Volumes/workspace/lhdw/bronze")
# Out:
# []

# %%
# Lista o conteúdo do Volume bronze
dbutils.fs.ls("/Volumes/workspace/lhdw/silver")
# Out:
# []

# %%
# Lista o conteúdo do Volume bronze
dbutils.fs.ls("/Volumes/workspace/lhdw/gold")
# Out:
# []

# %%
# Lista o conteúdo do repositorio da pasta processar
display(
dbutils.fs.ls("/Volumes/workspace/lhdw/landingzone/vendas/processar")
)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# Lista o conteúdo do repositorio da pasta processado
display(
dbutils.fs.ls("/Volumes/workspace/lhdw/landingzone/vendas/processado")
)
# Out:
# []

# %% [markdown]
# | Comando | Execução | Visualização |
# | :--- | :--- | :--- |
# | `%fs ls` | Rápida (Terminal) | Texto Simples |
# | `display(dbutils.fs.ls(...))` | Python | Tabela Formatada (HTML/Grid) |
